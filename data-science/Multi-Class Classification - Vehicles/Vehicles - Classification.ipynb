# %% [markdown]
# # "Vehicles." - транспортные средства

# %% [markdown]
# ### _"Recognizing vehicle type from its silhouette" (Classification task)._

# %% [markdown]
# ### «Определение типа транспортного средства по его силуэту» (Задание на классификацию).¶

# %% [markdown]
# ## Table of Contents
#
#
# ### Part 0: Introduction
#
# #### Overview
# The dataset that's we see here contains 19 columns and 846 entries of data about vehicle types.
#
# **Метаданные:**
#
# * **Class (target)** - класс
#
# * **COMPACTNESS** - компактность
#
# * **CIRCULARITY** - круговая форма
#
# * **DISTANCE_CIRCULARITY** - расстояние круговой формы
#
# * **RADIUS_RATIO** - соотношение радиусов
#
# * **PR.AXIS_ASPECT_RATIO** - соотношение сторон главной оси
#
# * **MAX.LENGTH_ASPECT_RATIO** - соотношение сторон максимальной длины
#
# * **SCATTER_RATIO** - соотношение рассеяния
#
# * **ELONGATEDNESS** - вытянутость
#
# * **PR.AXIS_RECTANGULARITY** - прямоугольность главной оси
#
# * **MAX.LENGTH_RECTANGULARITY** - прямоугольность максимальной длины
#
# * **SCALED_VARIANCE_MAJOR** - масштабированная дисперсия главной оси
#
# * **SCALED_VARIANCE_MINOR** - масштабированная дисперсия второстепенной оси
#
# * **SCALED_RADIUS_OF_GYRATION** - масштабированный радиус инерции
#
# * **SKEWNESS_ABOUT_MAJOR** - асимметрия по главной оси
#
# * **SKEWNESS_ABOUT_MINOR** - асимметрия по второстепенной оси
#
# * **KURTOSIS_ABOUT_MAJOR** - куртозис по главной оси
#
# * **KURTOSIS_ABOUT_MINOR** - куртозис по второстепенной оси
#
# * **HOLLOWS_RATIO** - соотношение пустот
#
#
# #### Questions:
#
# Определите класс транспортного средства по набору данных, описывающих геометрические особенности силуэтов транспортных средств, полученных по фотографиям для распознавания изображений (use multi-class classification; check balance of classes; calculate perdictions).
#
#
# ### [Part 1: Import, Load Data](#Part-1:-Import,-Load-Data.)
# * #### Import libraries, Read data from ‘.csv’ file
#
# ### [Part 2: Exploratory Data Analysis](#Part-2:-Exploratory-Data-Analysis.)
# * #### Info, Head, Describe
# * #### 'Class' attribute value counts and visualisation - подсчет и визуализация значений атрибута 'Class'
# * #### Label encoder for 'Class' attribute - кодирование атрибута 'Class'
# * #### Vizualisation of all attributes - визуализация всех атрибутов
# * #### Correlation plot of each attribute - график корреляции каждого атрибута
# * #### Correlation list of each attribute - список корреляций каждого атрибута
# * #### Drop column 'Class' - удаление столбца 'Class'
#
# ### [Part 3: Data Wrangling and Transformation](#Part-3:-Data-Wrangling-and-Transformation.)
# * #### StandardScaler - стандартизация значений
# * #### Creating datasets for ML part - создание наборов данных для части машинного обучения
# * #### 'Train\Test' splitting method - разделение на обучающую и тестовую выборки
#
# ### [Part 4: Machine Learning](#Part-4:-Machine-Learning.)
# * #### Build, train and evaluate model
#     * ##### SVC
#     * ##### Classification report
#     * ##### Confusion Matrix
#     * ##### Misclassification plot - график ошибочной классификации
#     * ##### Comparison table between Actual 'Class' and Predicted 'Class' - таблица сравнения между фактическим 'Class' и предсказанным 'Class'
#
# ### [Conclusion](#Conclusion.)

# %% [markdown]
# ## Part 1: Import, Load Data.

# %% [markdown]
# * ### Import libraries

# %%
# import standard libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import norm

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

from sklearn.svm import SVC
import warnings

# suppress warnings / скрыть предупреждения
warnings.filterwarnings('ignore')

# set plotting style - установка стиля печати
sns.set()
# %matplotlib inline

# %% [markdown]
# * ### Read data from ‘.csv’ file

# %%
# read data from '.csv' file
dataset = pd.read_csv('vehicles.csv') 

# initialisation of target
target = dataset['Class']

# %% [markdown]
# ## Part 2: Exploratory Data Analysis.

# %% [markdown]
# * ### Info

# %%
# print the full summary of the dataset / полная сводка датасета
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 846 entries, 0 to 845
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   COMPACTNESS                846 non-null    int64
#  1   CIRCULARITY                846 non-null    int64
#  2   DISTANCE_CIRCULARITY       846 non-null    int64
#  3   RADIUS_RATIO               846 non-null    int64
#  4   PR.AXIS_ASPECT_RATIO       846 non-null    int64
#  5   MAX.LENGTH_ASPECT_RATIO    846 non-null    int64
#  6   SCATTER_RATIO              846 non-null    int64
#  7   ELONGATEDNESS              846 non-null    int64
#  8   PR.AXIS_RECTANGULARITY     846 non-null    int64
#  9   MAX.LENGTH_RECTANGULARITY  846 non-null    int64
#  10  SCALED_VARIANCE_MAJOR      846 non-null    int64
#  11  SCALED_VARIANCE_MINOR      846 non-null    int64
#  12  SCALED_RADIUS_OF_GYRATION  846 non-null    int64
#  13  SKEWNESS_ABOUT_MAJOR       846 non-null    int64
#  14  SKEWNESS_ABOUT_MINOR       846 non-null    int64
#  15  KURTOSIS_ABOUT_MAJOR       846 non-null    int64
#  16  KURTOSIS_ABOUT_MINOR       846 non-null    int64
#  17  HOLLOWS_RATIO              846 non-null    int64
#  18  Class                      846 non-null    object
# dtypes: int64(18), object(1)
# memory usage: 125.7+ KB

# %% [markdown]
# ###### Dataset consists of 846 rows and 19 columns;
#
# has 2 datatypes: int64(18), object(1);
#
# has no missing values.

# %% [markdown]
# * ### Head

# %%
# preview of the first 5 lines of the loaded data 
dataset.head()
# Out:
#    COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0           95           48                    83           178
# 1           91           41                    84           141
# 2          104           50                   106           209
# 3           93           41                    82           159
# 4           85           44                    70           205
#
#    PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                    72                       10            162
# 1                    57                        9            149
# 2                    66                       10            207
# 3                    63                        9            144
# 4                   103                       52            149
#
#    ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# 0             42                      20                        159
# 1             45                      19                        143
# 2             32                      23                        158
# 3             46                      19                        143
# 4             45                      19                        144
#
#    SCALED_VARIANCE_MAJOR  SCALED_VARIANCE_MINOR  SCALED_RADIUS_OF_GYRATION  \
# 0                    176                    379                        184
# 1                    170                    330                        158
# 2                    223                    635                        220
# 3                    160                    309                        127
# 4                    241                    325                        188
#
#    SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  KURTOSIS_ABOUT_MAJOR  \
# 0                    70                     6                    16
# 1                    72                     9                    14
# 2                    73                    14                     9
# 3                    63                     6                    10
# 4                   127                     9                    11
#
#    KURTOSIS_ABOUT_MINOR  HOLLOWS_RATIO Class
# 0                   187            197   van
# 1                   189            199   van
# 2                   188            196  saab
# 3                   199            207   van
# 4                   180            183   bus

# %% [markdown]
# * ### Describe

# %%
dataset.describe()
# Out:
#        COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# count   846.000000   846.000000            846.000000    846.000000
# mean     93.678487    44.861702             82.088652    168.940898
# std       8.234474     6.169866             15.771533     33.472183
# min      73.000000    33.000000             40.000000    104.000000
# 25%      87.000000    40.000000             70.000000    141.000000
# 50%      93.000000    44.000000             80.000000    167.000000
# 75%     100.000000    49.000000             98.000000    195.000000
# max     119.000000    59.000000            112.000000    333.000000
#
#        PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# count            846.000000               846.000000     846.000000
# mean              61.693853                 8.567376     168.839243
# std                7.888251                 4.601217      33.244978
# min               47.000000                 2.000000     112.000000
# 25%               57.000000                 7.000000     146.250000
# 50%               61.000000                 8.000000     157.000000
# 75%               65.000000                10.000000     198.000000
# max              138.000000                55.000000     265.000000
#
#        ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# count     846.000000              846.000000                 846.000000
# mean       40.933806               20.582742                 147.998818
# std         7.811560                2.592138                  14.515652
# min        26.000000               17.000000                 118.000000
# 25%        33.000000               19.000000                 137.000000
# 50%        43.000000               20.000000                 146.000000
# 75%        46.000000               23.000000                 159.000000
# max        61.000000               29.000000                 188.000000
#
#        SCALED_VARIANCE_MAJOR  SCALED_VARIANCE_MINOR  \
# count             846.000000             846.000000
# mean              188.625296             439.911348
# std                31.394837             176.692614
# min               130.000000             184.000000
# 25%               167.000000             318.250000
# 50%               178.500000             364.000000
# 75%               217.000000             587.000000
# max               320.000000            1018.000000
#
#        SCALED_RADIUS_OF_GYRATION  SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  \
# count                  846.00000            846.000000            846.000000
# mean                   174.70331             72.462175              6.377069
# std                     32.54649              7.486974              4.918353
# min                    109.00000             59.000000              0.000000
# 25%                    149.00000             67.000000              2.000000
# 50%                    173.00000             71.500000              6.000000
# 75%                    198.00000             75.000000              9.000000
# max                    268.00000            135.000000             22.000000
#
#        KURTOSIS_ABOUT_MAJOR  KURTOSIS_ABOUT_MINOR  HOLLOWS_RATIO
# count            846.000000            846.000000     846.000000
# mean              12.599291            188.932624     195.632388
# std                8.931240              6.163949       7.438797
# min                0.000000            176.000000     181.000000
# 25%                5.000000            184.000000     190.250000
# 50%               11.000000            188.000000     197.000000
# 75%               19.000000            193.000000     201.000000
# max               41.000000            206.000000     211.000000

# %% [markdown]
# * ### 'Class' attribute value counts and visualisation

# %%
# target attribute value counts / количество целевых значений атрибутов
dataset['Class'].value_counts()
# Out:
# Class
# bus     218
# saab    217
# opel    212
# van     199
# Name: count, dtype: int64

# %%
# target attribute visualisation plot / график визуализации распределения целевых атрибутов
plt.figure(figsize=(6, 4))
sns.countplot(x='Class', data=dataset, palette='viridis')
plt.xlabel('Class', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Class Distribution', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Our dataset is balanced.

# %% [markdown]
# * ### Label encoder for 'Class' attribute

# %%
# label encoder for 'Class' attribute - кодирование атрибута 'Class'
le = LabelEncoder()
dataset['Class'] = le.fit_transform(dataset['Class'])
dataset.head()
# Out:
#    COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0           95           48                    83           178
# 1           91           41                    84           141
# 2          104           50                   106           209
# 3           93           41                    82           159
# 4           85           44                    70           205
#
#    PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                    72                       10            162
# 1                    57                        9            149
# 2                    66                       10            207
# 3                    63                        9            144
# 4                   103                       52            149
#
#    ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# 0             42                      20                        159
# 1             45                      19                        143
# 2             32                      23                        158
# 3             46                      19                        143
# 4             45                      19                        144
#
#    SCALED_VARIANCE_MAJOR  SCALED_VARIANCE_MINOR  SCALED_RADIUS_OF_GYRATION  \
# 0                    176                    379                        184
# 1                    170                    330                        158
# 2                    223                    635                        220
# 3                    160                    309                        127
# 4                    241                    325                        188
#
#    SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  KURTOSIS_ABOUT_MAJOR  \
# 0                    70                     6                    16
# 1                    72                     9                    14
# 2                    73                    14                     9
# 3                    63                     6                    10
# 4                   127                     9                    11
#
#    KURTOSIS_ABOUT_MINOR  HOLLOWS_RATIO  Class
# 0                   187            197      3
# 1                   189            199      3
# 2                   188            196      2
# 3                   199            207      3
# 4                   180            183      0

# %% [markdown]
# * ###  Vizualisation of all attributes

# %%
# vizualisation (first part of attributes)
attributes_part1 = ['Class', 'ELONGATEDNESS', 'SCALED_VARIANCE_MAJOR', 'SCALED_VARIANCE_MINOR', 'SCATTER_RATIO', 'PR.AXIS_RECTANGULARITY', 'HOLLOWS_RATIO']
df1 = dataset[attributes_part1]
sns.pairplot(df1, hue="Class", plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
plt.show()

# %%
# vizualisation (second part of attributes)
attributes_part2 = ['Class', 'SCALED_RADIUS_OF_GYRATION', 'SKEWNESS_ABOUT_MAJOR', 'MAX.LENGTH_ASPECT_RATIO', 'CIRCULARITY', 'RADIUS_RATIO', 'SKEWNESS_ABOUT_MINOR']
df2 = dataset[attributes_part2]
sns.pairplot(df2, hue="Class", plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
plt.show()

# %%
# vizualisation (third part of attributes)
attributes_part3 = ['Class', 'PR.AXIS_ASPECT_RATIO','KURTOSIS_ABOUT_MINOR','DISTANCE_CIRCULARITY','MAX.LENGTH_RECTANGULARITY','KURTOSIS_ABOUT_MAJOR','COMPACTNESS']
df3 = dataset[attributes_part3]
sns.pairplot(df3, hue="Class", plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))
plt.show()

# %% [markdown]
# * ###  Correlation plot of each attribute

# %%
# corelation plot 
plt.figure(figsize=(18, 6))
correlation = dataset.corr()['Class'].sort_values()
correlation.plot(kind='bar', color='skyblue')
plt.xlabel('Features', fontsize=14)
plt.ylabel('Correlation with Class', fontsize=14)
plt.title('Feature Correlation with Class', fontsize=16)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# * ###  Correlation list of each attribute

# %%
# correlation list - список корреляции
corr = dataset.corr()
corr_abs = corr.abs()
num_cols = len(dataset.columns)
num_corr = corr_abs.nlargest(num_cols, 'Class')['Class']
print(num_corr)
# Out:
# Class                        1.000000
# ELONGATEDNESS                0.326903
# SCALED_VARIANCE_MAJOR        0.300917
# SCALED_VARIANCE_MINOR        0.281097
# SCATTER_RATIO                0.280903
# PR.AXIS_RECTANGULARITY       0.249787
# HOLLOWS_RATIO                0.238360
# SCALED_RADIUS_OF_GYRATION    0.237618
# SKEWNESS_ABOUT_MAJOR         0.210035
# MAX.LENGTH_ASPECT_RATIO      0.195172
# CIRCULARITY                  0.174246
# RADIUS_RATIO                 0.173949
# SKEWNESS_ABOUT_MINOR         0.135965
# PR.AXIS_ASPECT_RATIO         0.090462
# KURTOSIS_ABOUT_MINOR         0.071960
# DISTANCE_CIRCULARITY         0.059804
# MAX.LENGTH_RECTANGULARITY    0.050632
# KURTOSIS_ABOUT_MAJOR         0.005710
# COMPACTNESS                  0.000434
# Name: Class, dtype: float64

# %% [markdown]
# * ### Drop column 'Class'

# %%
dataset = dataset.drop(columns=['Class'])

# %% [markdown]
# ## Part 3: Data Wrangling and Transformation.

# %% [markdown]
# * ### StandardScaler

# %%
# StandardScaler 
sc = StandardScaler()
dataset_sc = sc.fit_transform(dataset)
dataset_sc = pd.DataFrame(dataset_sc, columns=dataset.columns)
dataset_sc.head()
# Out:
#    COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0     0.160580     0.508950              0.057819      0.270806
# 1    -0.325470    -0.626268              0.121261     -0.835244
# 2     1.254193     0.833298              1.517005      1.197496
# 3    -0.082445    -0.626268             -0.005624     -0.297166
# 4    -1.054545    -0.139746             -0.766939      1.077923
#
#    PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0              1.307291                 0.311542      -0.205844
# 1             -0.595396                 0.094079      -0.597112
# 2              0.546217                 0.311542       1.148544
# 3              0.165679                 0.094079      -0.747600
# 4              5.239511                 9.444962      -0.597112
#
#    ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# 0       0.136570               -0.224944                   0.758332
# 1       0.520843               -0.610954                  -0.344578
# 2      -1.144341                0.933086                   0.689401
# 3       0.648935               -0.610954                  -0.344578
# 4       0.520843               -0.610954                  -0.275646
#
#    SCALED_VARIANCE_MAJOR  SCALED_VARIANCE_MINOR  SCALED_RADIUS_OF_GYRATION  \
# 0              -0.402383              -0.344935                   0.285812
# 1              -0.593611              -0.622416                  -0.513517
# 2               1.095564               1.104766                   1.392577
# 3              -0.912323              -0.741337                  -1.466565
# 4               1.669245              -0.650731                   0.408786
#
#    SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  KURTOSIS_ABOUT_MAJOR  \
# 0             -0.329056             -0.076711              0.380991
# 1             -0.061767              0.533610              0.156925
# 2              0.071877              1.550812             -0.403238
# 3             -1.264566             -0.076711             -0.291206
# 4              7.288670              0.533610             -0.179173
#
#    KURTOSIS_ABOUT_MINOR  HOLLOWS_RATIO
# 0             -0.313722       0.183957
# 1              0.010937       0.452977
# 2             -0.151393       0.049447
# 3              1.634233       1.529056
# 4             -1.450029      -1.699181

# %% [markdown]
# * ### Creating datasets for ML part

# %%
# set 'X' for features' and y' for the target ('Class').
X = dataset_sc.copy()
y = target

# %% [markdown]
# * ### 'Train\Test' split

# %%
# apply 'Train\Test' splitting method
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.24, random_state=0)

# %%
# print shape of X_train and y_train
X_train.shape, y_train.shape
# Out:
# ((642, 18), (642,))

# %%
# print shape of X_test and y_test
X_test.shape, y_test.shape
# Out:
# ((204, 18), (204,))

# %% [markdown]
# ## Part 4: Machine Learning.

# %% [markdown]
# * ### Build, train and evaluate model

# %% [markdown]
# * SVC model

# %%
# train the SVC classifier / обучение классификатора SVC
classifier = SVC(kernel='linear', decision_function_shape='ovo', tol=0.03)
classifier.fit(X_train, y_train)
SVC_pred = classifier.predict(X_test)
accuracy = accuracy_score(SVC_pred, y_test)
print("Accuracy:", accuracy * 100)
# Out:
# Accuracy: 80.88235294117648

# %% [markdown]
# * ### Classification report

# %%
# SVC Classification Report
print("SVC Classification Report: \n", classification_report(y_test, SVC_pred, digits=6))
# Out:
# SVC Classification Report:
#                precision    recall  f1-score   support
#
#          bus   0.901961  1.000000  0.948454        46
#         opel   0.653061  0.666667  0.659794        48
#         saab   0.727273  0.634921  0.677966        63
#          van   0.959184  1.000000  0.979167        47
#
#     accuracy                       0.808824       204
#    macro avg   0.810370  0.825397  0.816345       204
# weighted avg   0.802632  0.808824  0.804077       204

# %% [markdown]
# Вывод:
# * SVC linear model показывает достаточно хорошую метрику accuracy = 80.8% или 80.88235294117648;
# * Количество примеров классов представленных в тестовом сете данных (204 примера): "bus"=46, "opel"=48, "saab"=63, "van"=47;
# * По метрике f1-score сразу можно сказать, что лучше всех определился класс "van", за ним класс "bus", далее класс "saab", и хуже всех класс "opel". Давайте проверим это на confusion matrix.

# %% [markdown]
# * ### Confusion matrix

# %% [markdown]
# По диагонали (от верха слева до низа справа или самые темные квадраты с цифрами): кол-во верно предсказанных данных в определенном классе;
#
# По вертикали: сколько раз данный класс неверно предсказался в других классах (не учитывая диагональное число, суммируем все числа);
#
# По горизонтали: сколько раз другие классы неверно предсказались в данном классе (не учитывая диагональное число, суммируем все числа);

# %%
# confusion matrix of SVC model
labels = ["bus", "opel", "saab", "van"]
cm = confusion_matrix(y_test, SVC_pred, labels=None)
print('SVC Confusion Matrix')

# visualisation of matrix
df_cm = pd.DataFrame(cm, index=labels, columns=labels)
sns.heatmap(df_cm, annot=True, fmt="d", cmap='Blues', linewidths=0.5, annot_kws={'size': 15})
plt.ylabel("Actual Vehicle Class")
plt.xlabel("Predicted Vehicle Class")
plt.show()
# Out:
# SVC Confusion Matrix

# %% [markdown]
# * ### Misclassification plot

# %%
# misclassification vehicle plot - неверная классификация транспортного средства
for label in df_cm.columns:
    df_cm.at[label, label] = 0

ax = df_cm.plot(kind="bar", title="Misclassified Vehicle Classes")
ax.set_xlabel("Vehicle Classes")
ax.set_ylabel("Number of Incorrectly Predicted Class")
plt.show()

# %% [markdown]
# Вывод:
# * класс "van": _верно определен_ 47 раз из 47 примеров; _неверно определен в других классах_ 2 раза, _другие классы неверно определены в данном классе_ 0 раз.
# * класс "bus": _верно определен_ 46 раз из 46 примеров; _неверно определен в других классах_ 5 раз, _другие классы неверно определены в данном классе_ 0 раз.
# * класс "saab": _верно определен_ 40 раз из 63 примеров; _неверно определен в других классах_ 15 раз, _другие классы неверно определены в данном классе_ 23 раз.
# * класс "opel": _верно определен_ 32 раза из 48 примеров; _неверно определен в других классах_ 17 раз, _другие классы неверно определены в данном классе_ 16 раз.

# %% [markdown]
# * ### Comparison table between Actual 'Class' and Predicted 'Class'

# %%
# comparison table between Actual 'Class' and Predicted 'Class' / сравнительная таблица между фактическим «классом» и прогнозируемым «классом»
actualvspredicted = pd.DataFrame({"Actual Vehicle Class": y_test, "SVC Predicted Vehicle Class": SVC_pred})
actualvspredicted.head(10)
# Out:
#     Actual Vehicle Class SVC Predicted Vehicle Class
# 506                 saab                        opel
# 222                  bus                         bus
# 612                 opel                         van
# 730                 opel                        opel
# 661                 saab                        saab
# 577                 opel                        saab
# 31                  saab                         van
# 145                 opel                        opel
# 794                  bus                         bus
# 416                  bus                         bus

# %% [markdown]
# ##  Conclusion.

# %%
# submission of .csv file with test predictions
sub = pd.DataFrame()
sub['ID'] = X_test.index
sub['Class'] = SVC_pred
sub.to_csv('VehiclesPredictionsTest.csv', index=False)

# %% [markdown]
# **Question**: Определите класс транспортного средства по набору данных, описывающих геометрические особенности силуэтов транспортных средств, полученных по фотографиям для распознавания изображений (use multi-class classification; check balance of classes; calculate perdictions).
#
# **Answers**:
#
# 1. Multi-class classification was applied.
#
# 2. Classes were balanced in our dataset.
#
# 3. SVC model was used for ML process.
#
# 4. Result:
#     * Train/Test split: test_size=0.24, random_state=0;
#     * SVC linear model показывает достаточно хорошую метрику accuracy = 80.8% или 80.88235294117648;
#     * Сonfusion matrix показывает, что из 204 примеров тестовых данных были верно определены 165 примеров и неверно определены 39 примеров;
#     * Сonfusion matrix так же показывает, что самыми хорошо определяемыми классами являются "van" и "bus", а самыми трудно определяемыми "saab" и "opel".
